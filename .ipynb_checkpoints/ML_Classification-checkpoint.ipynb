# %% [markdown]
# # Machine Learning For Prediction
#
# We will use machine learning to predict whether a certain songs will be liked or disliked by me and with what probability. We will be using pipelines to teast several models at once and then use grid search to fine tune the parameters for better performance.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.model_selection import cross_val_predict
from sklearn import metrics
from sklearn import svm
# %matplotlib inline

# %%
likedf = pd.read_csv('A_like.csv')
dislikedf = pd.read_csv('A_dislike.csv')
likedf['like'] = 1
dislikedf['like'] = 0
combinedf = likedf.append(dislikedf)
combinedf.head()
# Out:
#                        id  liveness  loudness  \
# 0  7wrYBASu0OoxoDErd4Edxd    0.3160   -15.073
# 1  4esbIk42AvA2Zysz1V33SI    0.1680    -8.288
# 2  1xQ6trAsedVPCdbtDAmk0c    0.2690    -8.520
# 3  5RHUlxtZy1CeR4mGFftLoF    0.1660    -3.173
# 4  0DqWbva8nt0I7QTjXpjQEo    0.0416    -4.862
#
#                                         analysis_url  valence  mode  \
# 0  https://api.spotify.com/v1/audio-analysis/7wrY...    0.620     0
# 1  https://api.spotify.com/v1/audio-analysis/4esb...    0.450     0
# 2  https://api.spotify.com/v1/audio-analysis/1xQ6...    0.761     0
# 3  https://api.spotify.com/v1/audio-analysis/5RHU...    0.842     1
# 4  https://api.spotify.com/v1/audio-analysis/0DqW...    0.774     1
#
#    speechiness    tempo  key            type  acousticness  time_signature  \
# 0       0.0895  143.771   11  audio_features        0.5940               4
# 1       0.0638  143.974    3  audio_features        0.4910               4
# ...

# %%
# Remove columns
def features_removal(features_list):
    for i in features_list:
        combinedf.drop(i, axis = 1, inplace = True)
    return ';)'

# %%
features_removal(['analysis_url', 'mode', 'key', 'uri', 'type', 'time_signature', 'track_href', 'duration_ms'])
combinedf.head()
# Out:
#    liveness  loudness  valence  speechiness    tempo  acousticness  energy  \
# 0    0.3160   -15.073    0.620       0.0895  143.771        0.5940   0.268
# 1    0.1680    -8.288    0.450       0.0638  143.974        0.4910   0.498
# 2    0.2690    -8.520    0.761       0.0803  150.076        0.2340   0.481
# 3    0.1660    -3.173    0.842       0.0690  108.002        0.2030   0.933
# 4    0.0416    -4.862    0.774       0.0403  101.995        0.0633   0.532
#
#    danceability  instrumentalness  like
# 0         0.635          0.000002     1
# 1         0.626          0.000000     1
# 2         0.767          0.000000     1
# 3         0.722          0.000005     1
# 4         0.952          0.034300     1

# %%
combinedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 230
# Data columns (total 10 columns):
# liveness            447 non-null float64
# loudness            447 non-null float64
# valence             447 non-null float64
# speechiness         447 non-null float64
# tempo               447 non-null float64
# acousticness        447 non-null float64
# energy              447 non-null float64
# danceability        447 non-null float64
# instrumentalness    447 non-null float64
# like                447 non-null int64
# dtypes: float64(9), int64(1)
# memory usage: 38.4 KB

# %%
target = combinedf['like']
combinedf.drop('like', axis = 1, inplace = True)
combinedf.head()
# Out:
#    liveness  loudness  valence  speechiness    tempo  acousticness  energy  \
# 0    0.3160   -15.073    0.620       0.0895  143.771        0.5940   0.268
# 1    0.1680    -8.288    0.450       0.0638  143.974        0.4910   0.498
# 2    0.2690    -8.520    0.761       0.0803  150.076        0.2340   0.481
# 3    0.1660    -3.173    0.842       0.0690  108.002        0.2030   0.933
# 4    0.0416    -4.862    0.774       0.0403  101.995        0.0633   0.532
#
#    danceability  instrumentalness
# 0         0.635          0.000002
# 1         0.626          0.000000
# 2         0.767          0.000000
# 3         0.722          0.000005
# 4         0.952          0.034300

# %%
target.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: like, dtype: int64
